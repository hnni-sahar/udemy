# %% [markdown]
# ## Regression Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_ad_expenditure = pd.read_csv("C:/Users/sahar/Documents/Data/udemy/Regression_Plot/scatter_plot_ii.csv")
df_ad_expenditure
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %% [markdown]
# ### sns.regplot()

# %%
# A regplot accepts x and y in a variety of formats. For the lmplot the data need to be strings in the so called 'long-form'.

# plt.figure(figsize=(10,8))

# using seaborn
sns.set(rc={'figure.figsize' : (9,6)})# control the size of the figure with the rc dictionary
sns.regplot(x ='Budget', 
            y = 'Sales', 
            data = df_ad_expenditure,
            scatter_kws={'color':'k'},# color for the points
            line_kws={'color':'red'})# color for the regression line
plt.xlabel('Ad Expenditure in (000`s $ )' , fontsize=10 , weight='bold')
plt.ylabel('Sales in (000`s Units)', fontsize=10 , weight='bold')
plt.title('Effect of Ad Expenditure on Sales', fontsize=14 , weight='bold' )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### sns.lmplot()

# %%
sns.lmplot(x ='Budget',
           y = 'Sales',
           data = df_ad_expenditure,
           height = 10,# height and width of the plot
           scatter_kws={'color':'k'},# color for the points
           line_kws={'color':'red'})# color for the regression line
plt.xlabel('Ad Expenditure in (000`s $ )' , fontsize=10 , weight='bold')
plt.ylabel('Sales in (000`s Units)', fontsize=10 , weight='bold')
plt.title('Effect of Ad Expenditure on Sales', fontsize=14 , weight='bold' )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
