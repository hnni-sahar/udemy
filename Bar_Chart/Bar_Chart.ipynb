# %% [markdown]
# ## Bar Chart

# %%
import pandas as pd # library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization
sns.set() # this command sets the seaborn chart style as the default
from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %%
df_used_cars = pd.read_csv("C:/Users/sahar/Documents/Data/udemy/bar_chart/bar_chart_data.csv")
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
#determine the size of the chart
plt.figure(figsize=(9,6))

colors = ['r', 'g', 'b', 'w', 'y', 'm', 'c']  # List of valid color values

plt.bar(x=df_used_cars['Brand'], height=df_used_cars['Cars Listings'], color=colors[:len(df_used_cars['Brand'])])
plt.xticks(rotation = 45 , fontsize = 13)
plt.yticks(fontsize = 13)
plt.title('Cars Listing by Brand' , fontsize = (16) , fontweight = ('bold'))
plt.ylabel('Number of Listings', fontsize = (13) , fontweight = ('bold'))
plt.savefig('Used Cars Bar.jpeg') # you can export your chart as a picture
plt.show()
